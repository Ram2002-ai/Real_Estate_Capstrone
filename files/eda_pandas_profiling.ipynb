# %%
import pandas as pd
from pandas_profiling import ProfileReport

# load dastaset
df=pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# create the ProfileReport object
profile=ProfileReport(df,title="Pandas Profilling Report",explorative=True)

# Generate the report
profile.to_file('output_report.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# %|                                                                                           | 0/23 [00:00<?, ?it/s]
# %|███████▏                                                                           | 2/23 [00:00<00:02,  8.94it/s]
# %|█████████████████████████▎                                                         | 7/23 [00:00<00:01,  9.94it/s]
# %|█████████████████████████████████████████████████████▍                            | 15/23 [00:00<00:00, 22.56it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 24.79it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# !pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting joblib~=1.1.0 (from pandas-profiling)
#   Downloading joblib-1.1.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\user\anaconda3\lib\site-packages (from pandas-profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\user\anaconda3\lib\site-packages (from pandas-profiling) (2.2.3)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\user\anaconda3\lib\site-packages (from pandas-profiling) (3.10.0)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\user\anaconda3\lib\site-packages (from pandas-profiling) (2.10.3)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\user\anaconda3\lib\site-packages (from pandas-profiling) (6.0.2)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\user\anaconda3\lib\site-packages (from pandas-profiling) (3.1.6)
# Collecting markupsafe~=2.1.1 (from pandas-profiling)
#   Downloading MarkupSafe-2.1.5.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting visions==0.7.4 (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\user\anaconda3\lib\site-packages (from pandas-profiling) (2.1.3)
# Collecting htmlmin>=0.1.12 (from pandas-profiling)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [19 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#       exec(compile('''
#       ~~~~^^^^^^^^^^^^
#       # This is <pip-setuptools-caller> -- a caller that pip uses to run setup.py
#       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       ...<32 lines>...
#       exec(compile(setup_py_code, filename, "exec"))
#       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       ''' % ('C:\\Users\\USER\\AppData\\Local\\Temp\\pip-install-0q88w_v3\\htmlmin_1c08badca51f4d838316799179fbf082\\setup.py',), "<pip-setuptools-caller>", "exec"))
#       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "<pip-setuptools-caller>", line 35, in <module>
#     File "C:\Users\USER\AppData\Local\Temp\pip-install-0q88w_v3\htmlmin_1c08badca51f4d838316799179fbf082\setup.py", line 4, in <module>
#       from htmlmin import __version__
#     File "C:\Users\USER\AppData\Local\Temp\pip-install-0q88w_v3\htmlmin_1c08badca51f4d838316799179fbf082\htmlmin\__init__.py", line 28, in <module>
#       from .main import minify, Minifier
#     File "C:\Users\USER\AppData\Local\Temp\pip-install-0q88w_v3\htmlmin_1c08badca51f4d838316799179fbf082\htmlmin\main.py", line 28, in <module>
#       import cgi
#   ModuleNotFoundError: No module named 'cgi'
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
pip install ydata-profiling
# Out:
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.18.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: scipy<1.17,>=1.8 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (2.2.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (2.10.3)
# Collecting PyYAML<6.1,>=6.0.3 (from ydata-profiling)
#   Using cached pyyaml-6.0.3-cp313-cp313-win_amd64.whl.metadata (2.4 kB)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (3.1.6)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.4,>=1.22 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (2.1.3)
# Collecting minify-html>=0.15.0 (from ydata-profiling)
#   Downloading minify_html-0.18.1-cp313-cp313-win_amd64.whl.metadata (18 kB)
# Collecting filetype>=1.0.0 (from ydata-profiling)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting phik<0.13,>=0.12.5 (from ydata-profiling)
#   Downloading phik-0.12.5-cp313-cp313-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.32.0 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.66.3 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (0.14.4)
# Collecting typeguard<5,>=4 (from ydata-profiling)
#   Downloading typeguard-4.4.4-py3-none-any.whl.metadata (3.3 kB)
# Collecting imagehash==4.3.2 (from ydata-profiling)
#   Downloading ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting wordcloud>=1.9.4 (from ydata-profiling)
#   Downloading wordcloud-1.9.6-cp313-cp313-win_amd64.whl.metadata (3.5 kB)
# Collecting dacite<2,>=1.9 (from ydata-profiling)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numba<0.63,>=0.60 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (0.61.0)
# Requirement already satisfied: PyWavelets in c:\users\user\anaconda3\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (1.8.0)
# Requirement already satisfied: pillow in c:\users\user\anaconda3\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\user\anaconda3\lib\site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\user\anaconda3\lib\site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\user\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\user\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2025.11.12)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\user\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.1)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm<5,>=4.66.3->ydata-profiling) (0.4.6)
# Collecting typing-extensions>=4.12.2 (from pydantic<3,>=2->ydata-profiling)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\user\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (24.3.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\user\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.4.2)
# Collecting puremagic (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading puremagic-1.30-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# Downloading ydata_profiling-4.18.1-py2.py3-none-any.whl (400 kB)
# Downloading ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading phik-0.12.5-cp313-cp313-win_amd64.whl (678 kB)
#    ---------------------------------------- 0.0/678.1 kB ? eta -:--:--
#    ---------------------------------------- 678.1/678.1 kB 9.4 MB/s eta 0:00:00
# Using cached pyyaml-6.0.3-cp313-cp313-win_amd64.whl (154 kB)
# Downloading typeguard-4.4.4-py3-none-any.whl (34 kB)
# Downloading visions-0.8.1-py3-none-any.whl (105 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading minify_html-0.18.1-cp313-cp313-win_amd64.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ------------------------------------- -- 2.9/3.1 MB 16.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 14.6 MB/s eta 0:00:00
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading wordcloud-1.9.6-cp313-cp313-win_amd64.whl (306 kB)
# Downloading puremagic-1.30-py3-none-any.whl (43 kB)
# Installing collected packages: puremagic, minify-html, filetype, typing-extensions, PyYAML, multimethod, dacite, typeguard, imagehash, wordcloud, visions, phik, ydata-profiling
#
#    ------ ---------------------------------  2/13 [filetype]
#   Attempting uninstall: typing-extensions
#    ------ ---------------------------------  2/13 [filetype]
#     Found existing installation: typing_extensions 4.12.2
#    ------ ---------------------------------  2/13 [filetype]
#     Uninstalling typing_extensions-4.12.2:
#    ------ ---------------------------------  2/13 [filetype]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#       Successfully uninstalled typing_extensions-4.12.2
#    --------- ------------------------------  3/13 [typing-extensions]
#    --------- ------------------------------  3/13 [typing-extensions]
#   Attempting uninstall: PyYAML
#    --------- ------------------------------  3/13 [typing-extensions]
#     Found existing installation: PyYAML 6.0.2
#    --------- ------------------------------  3/13 [typing-extensions]
#     Uninstalling PyYAML-6.0.2:
#    --------- ------------------------------  3/13 [typing-extensions]
#       Successfully uninstalled PyYAML-6.0.2
#    --------- ------------------------------  3/13 [typing-extensions]
#    ------------ ---------------------------  4/13 [PyYAML]
#    ------------ ---------------------------  4/13 [PyYAML]
#    ------------ ---------------------------  4/13 [PyYAML]
#    ------------ ---------------------------  4/13 [PyYAML]
#    ------------ ---------------------------  4/13 [PyYAML]
#    ------------ ---------------------------  4/13 [PyYAML]
#    ------------ ---------------------------  4/13 [PyYAML]
#    ------------ ---------------------------  4/13 [PyYAML]
#    ------------ ---------------------------  4/13 [PyYAML]
#    ------------ ---------------------------  4/13 [PyYAML]
#    ------------ ---------------------------  4/13 [PyYAML]
#    ------------ ---------------------------  4/13 [PyYAML]
#    ------------ ---------------------------  4/13 [PyYAML]
#    ------------ ---------------------------  4/13 [PyYAML]
#    ------------ ---------------------------  4/13 [PyYAML]
#    ------------ ---------------------------  4/13 [PyYAML]
#    ------------ ---------------------------  4/13 [PyYAML]
#    ------------ ---------------------------  4/13 [PyYAML]
#    --------------- ------------------------  5/13 [multimethod]
#    --------------------- ------------------  7/13 [typeguard]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    --------------------------------- ------ 11/13 [phik]
#    --------------------------------- ------ 11/13 [phik]
#    ------------------------------------ --- 12/13 [ydata-profiling]
#    ------------------------------------ --- 12/13 [ydata-profiling]
#    ------------------------------------ --- 12/13 [ydata-profiling]
#    ------------------------------------ --- 12/13 [ydata-profiling]
#    ------------------------------------ --- 12/13 [ydata-profiling]
#    ------------------------------------ --- 12/13 [ydata-profiling]
#    ---------------------------------------- 13/13 [ydata-profiling]
#
# Successfully installed PyYAML-6.0.3 dacite-1.9.2 filetype-1.2.0 imagehash-4.3.2 minify-html-0.18.1 multimethod-1.12 phik-0.12.5 puremagic-1.30 typeguard-4.4.4 typing-extensions-4.15.0 visions-0.8.1 wordcloud-1.9.6 ydata-profiling-4.18.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\USER\anaconda3\Lib\site-packages\~aml'.
#   You can safely remove it manually.
