# %%
import numpy as np
import pandas as pd

# %%
flates=pd.read_csv('flats_cleaned.csv')
houses=pd.read_csv('house_cleaned.csv')

# %%
df=pd.concat([flates,houses],ignore_index=True)

# %%
df.sample(df.shape[0])
# Out:
#                                        property_name property_type  \
# 2474         4 Bedroom House for sale in Maruti Kunj         house
# 2418                 3 BHK Flat in Sector 79 Gurgaon          flat
# 1576    12 Bedroom House for sale in Uppals Southend         house
# 306                 4 BHK Flat in Sector 113 Gurgaon          flat
# 3532        14 Bedroom House for sale in DLF Phase 3         house
# ...                                              ...           ...
# 2963  16 Bedroom House for sale in Sector 40 Gurgaon         house
# 2498                4 BHK Flat in Sector 82A Gurgaon          flat
# 1426                 4 BHK Flat in Sector 92 Gurgaon          flat
# 1586  3 Bedroom House for sale in Sector 23A Gurgaon         house
# 1213                 4 BHK Flat in Sector 81 Gurgaon          flat
#
#                                         society  price  price_per_sqft  \
# 2474                                independent   0.70          4117.0
# ...

# %%
df=df.sample(df.shape[0],ignore_index=True) #to remove the biasness from the dataset

# %%
df.head()
# Out:
#                                     property_name property_type  \
# 0                       4 BHK Flat in DLF Phase 3          flat
# 1                3 BHK Flat in Sector 109 Gurgaon          flat
# 2                 3 BHK Flat in Sector 89 Gurgaon          flat
# 3                 4 BHK Flat in Sector 90 Gurgaon          flat
# 4  5 Bedroom House for sale in Sector 111 Gurgaon         house
#
#                        society  price  price_per_sqft         area  \
# 0       dlf city plots phase 3   6.50         18571.0  3500.080771
# 1  brisk lumbini terrace homes   1.50          6616.0  2267.230955
# 2             smart world gems   1.71         12000.0  1425.000000
# 3            dlf regal gardens   1.65          7449.0  2215.062424
# 4       puri diplomatic greens   9.00         11250.0  8000.000000
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                   Carpet area: 3500 (325.16 sq.m.)        4         5
# ...
